# %%
# <<< SECCION 23 MODULO SEARBORN Y MATPLOTLIB >>>  Ejercicio 1

# %% [markdown]
# Crea una lista de 1000 valores aleatorios que siga una distribucion normal
#
# Crea un hostograma mediante matplotlib con una lista de valores
#
# Crea un diagrama de caja (donde se acomula el 50 % de los valores) mediante seaborn

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
lista_valores = np.random.randn(1000)

# %%
lista_valores
# Out:
# array([-2.26178242e+00,  3.19382210e-01, -3.19991942e-01, -7.98094757e-01,
#         1.98463751e+00,  6.76506761e-02,  5.73329786e-01,  2.00804072e-01,
#         1.76615798e-02,  1.97178738e-01, -1.78649425e+00, -1.12355008e+00,
#        -2.19325029e-01, -4.92493825e-01, -1.89112520e-01, -5.16716144e-01,
#         5.35284244e-02,  2.14809960e+00,  1.28051777e+00,  8.20287810e-01,
#         4.53721521e-01,  1.02736957e+00,  1.66775450e+00,  1.34290521e+00,
#        -8.41779094e-01,  6.97464473e-02,  1.23528344e+00,  6.32999932e-01,
#         7.83864694e-01,  8.19122105e-01,  1.41622729e+00,  6.51496020e-01,
#         6.91865840e-01,  8.05951359e-01,  4.05756402e-01, -1.53751059e+00,
#         7.81915746e-01, -5.16636686e-02,  2.33423405e+00, -7.67493434e-02,
#         7.21636653e-01, -7.21781356e-01,  2.06717748e+00,  4.24191239e-01,
#         8.04696836e-01,  6.34130844e-01,  1.63684244e-01, -6.68449763e-01,
# ...

# %%
plt.hist(lista_valores)
# Out:
# (array([  9.,  16.,  76., 169., 257., 240., 150.,  60.,  18.,   5.]),
#  array([-3.13714491, -2.48883618, -1.84052745, -1.19221872, -0.54390999,
#          0.10439874,  0.75270747,  1.4010162 ,  2.04932493,  2.69763365,
#          3.34594238]),
#  <a list of 10 Patch objects>)
